# %%
import os
import pickle

base_path = r'D:\AI ML ENGINEERING JOURNY\03_Machine_Learning\scikit-learn\Basic of Scikit Learn\models'

os.makedirs(base_path, exist_ok=True)

with open(os.path.join(base_path, 'ohe_sex.pkl'), 'wb') as f:
    pickle.dump(ohe_sex, f)

with open(os.path.join(base_path, 'ohe_embarked.pkl'), 'wb') as f:
    pickle.dump(ohe_embarked, f)

with open(os.path.join(base_path, 'clf.pkl'), 'wb') as f:
    pickle.dump(clf, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 9
#       6 os.makedirs(base_path, exist_ok=True)
#       8 with open(os.path.join(base_path, 'ohe_sex.pkl'), 'wb') as f:
# ----> 9     pickle.dump(ohe_sex, f)
#      11 with open(os.path.join(base_path, 'ohe_embarked.pkl'), 'wb') as f:
#      12     pickle.dump(ohe_embarked, f)
#
# NameError: name 'ohe_sex' is not defined

# %%
# Assume user input
# Pclass/gender/age/SibSp/Parch/Fare/Embarked
test_input = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_input_sex = ohe_sex.transform(test_input[:,1].reshape(1,1))

# %%
test_input_sex
# Out:
# array([[0., 1.]])

# %%
test_input_embarked = ohe_embarked.transform(test_input[:,-1].reshape(1,1))

# %%
test_input_embarked
# Out:
# array([[0., 0., 1.]])

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)

# %%
test_input_transformed.shape
# Out:
# (1, 10)

# %%
clf.predict(test_input_transformed)
# Out:
# array([1], dtype=int64)
