# %% [markdown]
# # Naive_Bayes

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("/home/ipartzix/Downloads/play_tennis.csv")

# %%
df.head()
# Out:
#   day   outlook  temp humidity    wind play
# 0  D1     Sunny   Hot     High    Weak   No
# 1  D2     Sunny   Hot     High  Strong   No
# 2  D3  Overcast   Hot     High    Weak  Yes
# 3  D4      Rain  Mild     High    Weak  Yes
# 4  D5      Rain  Cool   Normal    Weak  Yes

# %%
df["play"].value_counts()
# Out:
# play
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
# probabilit of yes and no
pYes = 9/14
pNo = 5/14

# %%
pd.crosstab(df["outlook"], df["play"])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
# outlook 
pon = 0
pro = 2/5
psn = 3/5

poy = 4/9
pry= 3/9
psy = 2/9

# %%
pd.crosstab(df["temp"], df["play"])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
# temp
pcoldNo = 1/5
photNo = 2/5
pmildNo = 2/5

pcoldYes = 3/9
photYes  = 2/9
pmildYes = 4/9

# %%
pd.crosstab(df["humidity"], df["play"])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
# humidity	
phighNo = 4/5
plowNo = 1/5

phighYes = 3/9
plowYes = 6/9

# %%
pd.crosstab(df["wind"], df["play"])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
# wind
pstrongNo = 3/5
pweakNo = 2/5

pstrongYes = 3/9
pweakYes = 6/9
