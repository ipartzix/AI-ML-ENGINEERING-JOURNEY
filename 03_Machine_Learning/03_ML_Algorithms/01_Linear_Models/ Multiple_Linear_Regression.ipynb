# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# ## Definition
#
# Multiple Linear Regression (MLR) models the relationship between one dependent variable and two or more independent variables.
#
# It extends simple linear regression to higher dimensions.

# %% [markdown]
# ## 2. Mathematical Model
#
# 𝑦=𝛽0+𝛽1𝑥1+𝛽2𝑥2+⋯+𝛽𝑛𝑥𝑛+𝜖
# Where:
# - y → Dependent (target) variable
# - x1 , x2 , x3 ...xn → Independent variables
# - β0 → Intercept
# - 𝛽0+𝛽1,...𝛽n → Coefficients
# - ϵ → Error term

# %% [markdown]
# ## 3. Key Idea
# - The model fits a hyperplane (not a line) in multi-dimensional space.
# - Each feature contributes linearly to the output.

# %% [markdown]
# ## 4. Example
#
# Predict house price using:
#
# - Area (𝑥1)
# - Number of rooms (𝑥2)
# - Location score (𝑥3)
# - Model:
#        ```  Price=β0​+β1​(Area)+β2​(Rooms)+β3​(Location)```

# %% [markdown]
# ## Assumptions
#
# MLR works properly only if these conditions hold:
#
# - Linearity:-
# Relationship between input and output is linear
# - Independence of errors:-
# Residuals are not correlated
# - Homoscedasticity:-
# Constant variance of errors
# - No Multicollinearity:-
# Independent variables should not be highly correlated
# - Normality of residuals:-
# Errors should follow normal distribution

# %% [markdown]
# ## Cost Function (Loss Function)
# J(β)=n1​∑i=1n​(yi​−y^​i​)2
# - This is Mean Squared Error (MSE)
# - Goal: Minimize error between actual and predicted values

# %% [markdown]
# ## Methods to Find Coefficients
# - Normal Equation
# - Gradient Descent (used for large datasets)
# - OLS (Ordinary Least Squares)

# %% [markdown]
# ## Evaluation Metrics
#
# Used to measure model performance:
#
# - R² Score (Coefficient of Determination)
# - Adjusted R²
# - Mean Absolute Error (MAE)
# - Mean Squared Error (MSE)
# - Root Mean Squared Error (RMSE)

# %% [markdown]
# ## Advantages
# - Simple and interpretable
# - Works well for linear relationships
# - Fast to train

# %% [markdown]
# ##  Disadvantages
# - Cannot capture non-linear patterns
# - Sensitive to outliers
# - Multicollinearity can break the model
# - Assumptions must hold

# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    feature1  feature2     target
# 0 -0.443427 -0.103898  -6.223665
# 1  0.926955 -1.425823  12.932866
# 2 -1.821654 -1.121037 -49.406336
# 3  0.896395 -0.832448  67.069146
# 4  0.763288  0.987228  32.732161

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 48.323560135450414
# MSE 3142.844772299081
# R2 score 0.2653824240313061

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)

xGrid, yGrid = np.meshgrid(x, y)

# Create input features (100 samples, 2 features)
final = np.vstack((xGrid.ravel(), yGrid.ravel())).T

# Predict
z_final = lr.predict(final)

# Reshape to grid
z = z_final.reshape(10, 10)

# %%
lr.coef_
# Out:
# array([26.27345415,  6.1350301 ])

# %%
lr.intercept_
# Out:
# np.float64(0.5081240166719212)
