# %% [markdown]
# # Handling Missing Categorical Data

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/refs/heads/main/day37-handling-missing-categorical-data/train.csv",usecols=["GarageQual","FireplaceQu","SalePrice"])

# %%
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df["GarageQual"].value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel("GarageQual")
plt.ylabel("number of houses ")
# Out:
# Text(0, 0.5, 'number of houses ')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original
df['SalePrice'].plot(kind='kde', ax=ax)

# imputed (example: replace NaN with 'TA')
df_imputed = df.copy()
df_imputed['GarageQual'] = df_imputed['GarageQual'].fillna('TA')

df_imputed['SalePrice'].plot(kind='kde', ax=ax, color='red')

ax.legend(['Original', 'After Imputation'])
plt.title('Effect of GarageQual Imputation on SalePrice')
# Out:
# Text(0.5, 1.0, 'Effect of GarageQual Imputation on SalePrice')
